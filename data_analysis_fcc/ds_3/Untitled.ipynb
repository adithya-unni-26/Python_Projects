# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import *
import seaborn as sn
import numpy as np
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters() # this gives matplotlib info about pd objects. Here pd.timestamp object is used.

# %%
df=pd.read_csv('fcc-forum-pageviews.csv')
df['date']=pd.to_datetime(df['date'])
df=df.loc[~(((df['value'])>(df['value'].quantile(.975))) | ((df['value'])<(df['value'].quantile(.025))))]

# %%
# Out:
# date     datetime64[ns]
# value             int64
# dtype: object

# %%
df=df.loc[~(((df['value'])>(df['value'].quantile(.975))) | ((df['value'])<(df['value'].quantile(.025))))]

# %%
df.set_index('date',inplace=True)

# %%
plt.plot(df)
plt.tight_layout()
plt.title('Daily freeCodeCamp Forum Page Views 5/2016-12/2019')
plt.xlabel('Date')
plt.ylabel('PageViews')
plt.savefig('line_plot.png')

# %%
fig=plt.figure(figsize=(20, 5))
ax = fig.add_subplot(111)
ax.plot(df)
plt.title('Daily freeCodeCamp Forum Page Views 5/2016-12/2019')
plt.xlabel('Date')
plt.ylabel('PageViews')
plt.savefig('line_plot.png')

# %%
df=pd.read_csv('fcc-forum-pageviews.csv')

# %%
df=df.loc[~(((df['value'])>(df['value'].quantile(.975))) | ((df['value'])<(df['value'].quantile(.025))))]

# %%
df['date']=pd.to_datetime(df['date'])
df['year']=pd.DatetimeIndex(df['date']).year
df['month']=pd.DatetimeIndex(df['date']).month_name()

# %%
df.drop(columns='date')
# Out:
#        value  year     month
# 10     19736  2016       May
# 17     18060  2016       May
# 18     19997  2016       May
# 19     19044  2016       May
# 20     20325  2016       May
# ...      ...   ...       ...
# 1294  138875  2019  November
# 1299  171584  2019  November
# 1300  141161  2019  November
# 1301  142918  2019  December
# 1303  158549  2019  December
#
# [1238 rows x 3 columns]

# %%
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sn.barplot(ax=ax,data=df,y='value',x='year',hue='month',hue_order=['January','February','March','April','May','June','July','August','September','October','November','December'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='value'>

# %%
ax.set(ylabel='Average Page Views')
# Out:
# [Text(17.200000000000003, 0.5, 'Average Page Views')]

# %%
fig

# %%
fig.savefig('barplot.png')

# %%
# df.drop(columns='date',inplace=True)

# %%
# df.reset_index(inplace=True)

# %%
# df.drop(columns='index',inplace=True)

# %%
# df.groupby('month').count()
# Out:
#            value  year
# month
# April         90    90
# August       122   122
# December      95    95
# February      84    84
# January       93    93
# July         120   120
# June         107   107
# March         93    93
# May           98    98
# November     104   104
# October      112   112
# September    120   120

# %%
df
# Out:
#        value  year     month
# 0      19736  2016       May
# 1      18060  2016       May
# 2      19997  2016       May
# 3      19044  2016       May
# 4      20325  2016       May
# ...      ...   ...       ...
# 1233  138875  2019  November
# 1234  171584  2019  November
# 1235  141161  2019  November
# 1236  142918  2019  December
# 1237  158549  2019  December
#
# [1238 rows x 3 columns]

# %%
df=pd.read_csv('fcc-forum-pageviews.csv')
df['date']=pd.to_datetime(df['date'])
df=df.loc[~(((df['value'])>(df['value'].quantile(.975))) | ((df['value'])<(df['value'].quantile(.025))))]

# %%
df['date']=pd.to_datetime(df['date'])
df['year']=pd.DatetimeIndex(df['date']).year
df['month']=pd.DatetimeIndex(df['date']).month

# %%
df
# Out:
#            date   value  year  month
# 10   2016-05-19   19736  2016      5
# 17   2016-05-26   18060  2016      5
# 18   2016-05-27   19997  2016      5
# 19   2016-05-28   19044  2016      5
# 20   2016-05-29   20325  2016      5
# ...         ...     ...   ...    ...
# 1294 2019-11-24  138875  2019     11
# 1299 2019-11-29  171584  2019     11
# 1300 2019-11-30  141161  2019     11
# 1301 2019-12-01  142918  2019     12
# 1303 2019-12-03  158549  2019     12
#
# [1238 rows x 4 columns]

# %%
look_up = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May',
            6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}

# %%
df['month'] = df['month'].apply(lambda x: look_up[x])

# %%
df
# Out:
#            date   value  year month
# 10   2016-05-19   19736  2016   May
# 17   2016-05-26   18060  2016   May
# 18   2016-05-27   19997  2016   May
# 19   2016-05-28   19044  2016   May
# 20   2016-05-29   20325  2016   May
# ...         ...     ...   ...   ...
# 1294 2019-11-24  138875  2019   Nov
# 1299 2019-11-29  171584  2019   Nov
# 1300 2019-11-30  141161  2019   Nov
# 1301 2019-12-01  142918  2019   Dec
# 1303 2019-12-03  158549  2019   Dec
#
# [1238 rows x 4 columns]

# %%
sn.set_style("whitegrid")

# %%
fig, ax = plt.subplots(figsize=a4_dims)

# %%
sn.boxplot(x = 'year', y = 'value', data=df,ax=ax)
# Out:
# <AxesSubplot:xlabel='year', ylabel='value'>

# %%
fig.savefig('boxplot_1.png')

# %%
sn.boxplot(x = 'month', y = 'value', data=df,ax=ax)
# Out:
# <AxesSubplot:xlabel='month', ylabel='value'>

# %%
fig.savefig('boxplot_2.png')
