# %%
import pandas as pd

# %%
df=pd.read_csv('adult.data.csv')

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
race_series=df.groupby('race').count()['age'].sort_values(ascending=False)

# %%
race_series
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: age, dtype: int64

# %%
average_age=df['age'].mean()

# %%
average_age
# Out:
# 38.58164675532078

# %%
df.groupby('education').count()['age'].sum()
# Out:
# 32561

# %%
percentage_bachelors=(df.groupby('education').count()['age']['Bachelors']/df.groupby('education').count()['age'].sum()*100)

# %%
percentage_bachelors.round(1)
# Out:
# 16.4

# %%
work_hours=df['hours-per-week'].min()

# %%
new_df=df.loc[df['hours-per-week']==work_hours]

# %%
new_df.groupby('salary').count()
# Out:
#         age  workclass  fnlwgt  education  education-num  marital-status  \
# salary
# <=50K    18         18      18         18             18              18
# >50K      2          2       2          2              2               2
#
#         occupation  relationship  race  sex  capital-gain  capital-loss  \
# salary
# <=50K           18            18    18   18            18            18
# >50K             2             2     2    2             2             2
#
#         hours-per-week  native-country
# salary
# <=50K               18              18
# >50K                 2               2

# %%
2/20 *100
# Out:
# 10.0

# %%
country_50k=df.loc[df['salary']=='>50K'].groupby('native-country').count()['age']

# %%
country_pop=df.groupby('native-country').count()['age']

# %%
india_df.groupby('salary').count()
# Out:
#          age  workclass  fnlwgt  education  education-num  marital-status  \
# salary
# >50K    7841       7841    7841       7841           7841            7841
#
#         occupation  relationship  race   sex  capital-gain  capital-loss  \
# salary
# >50K          7841          7841  7841  7841          7841          7841
#
#         hours-per-week  native-country
# salary
# >50K              7841            7841

# %%
country_50k
# Out:
# native-country
# ?                      146
# Cambodia                 7
# Canada                  39
# China                   20
# Columbia                 2
# Cuba                    25
# Dominican-Republic       2
# Ecuador                  4
# El-Salvador              9
# England                 30
# France                  12
# Germany                 44
# Greece                   8
# Guatemala                3
# Haiti                    4
# Honduras                 1
# Hong                     6
# Hungary                  3
# India                   40
# Iran                    18
# Ireland                  5
# Italy                   25
# Jamaica                 10
# Japan                   24
# Laos                     2
# Mexico                  33
# Nicaragua                2
# Peru                     2
# Philippines             61
# Poland                  12
# Portugal                 4
# Puerto-Rico             12
# Scotland                 3
# ...

# %%
ha_df=pd.concat([country_pop,country_50k], axis=1)
ha_df.columns=['pop','fifty']

# %%
ha_df
# Out:
#                               pop   fifty
# native-country
# ?                             583   146.0
# Cambodia                       19     7.0
# Canada                        121    39.0
# China                          75    20.0
# Columbia                       59     2.0
# Cuba                           95    25.0
# Dominican-Republic             70     2.0
# Ecuador                        28     4.0
# El-Salvador                   106     9.0
# England                        90    30.0
# France                         29    12.0
# Germany                       137    44.0
# Greece                         29     8.0
# Guatemala                      64     3.0
# Haiti                          44     4.0
# Holand-Netherlands              1     NaN
# Honduras                       13     1.0
# Hong                           20     6.0
# Hungary                        13     3.0
# India                         100    40.0
# Iran                           43    18.0
# ...

# %%
ha_df['percentage']=ha_df.apply(lambda x:(x['fifty']/x['pop'])*100,axis=1)

# %%
ha_df['percentage'].max().round(1)
# Out:
# 41.9

# %%
df.loc[(df['native-country']=='India') & (df['salary']=='>50K')].groupby('occupation').count()
# Out:
#                   age  workclass  fnlwgt  education  education-num  \
# occupation
# Adm-clerical        1          1       1          1              1
# Exec-managerial     8          8       8          8              8
# Other-service       2          2       2          2              2
# Prof-specialty     25         25      25         25             25
# Sales               1          1       1          1              1
# Tech-support        2          2       2          2              2
# Transport-moving    1          1       1          1              1
#
#                   marital-status  relationship  race  sex  capital-gain  \
# occupation
# Adm-clerical                   1             1     1    1             1
# Exec-managerial                8             8     8    8             8
# Other-service                  2             2     2    2             2
# Prof-specialty                25            25    25   25            25
# ...

# %%
df.loc[~((df['education']=='Bachelors')| (df['education']=='Masters')| (df['education']=='Doctorate'))].groupby('salary').count()
# Out:
#           age  workclass  fnlwgt  education  education-num  marital-status  \
# salary
# <=50K   20715      20715   20715      20715          20715           20715
# >50K     4355       4355    4355       4355           4355            4355
#
#         occupation  relationship   race    sex  capital-gain  capital-loss  \
# salary
# <=50K        20715         20715  20715  20715         20715         20715
# >50K          4355          4355   4355   4355          4355          4355
#
#         hours-per-week  native-country
# salary
# <=50K            20715           20715
# >50K              4355            4355

# %%
a=3486/7491 *100

# %%
round(a,2)
# Out:
# 46.54

# %%
b=4355/20715 *100

# %%
round(b,2)
# Out:
# 21.02
